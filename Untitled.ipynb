# %%
import plotly.express as px
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.tools import FigureFactory as FF

import json
import numpy as np
import pandas as pd

# %%
df_merged = pd.read_excel("df_full.xlsx")

# %%
df_merged.head(5)
# Out:
#    Unnamed: 0  Rnd  Pick   Tm        Player Pos_x   Age      To  Misc_AP1  \
# 0           0  1.0   1.0  SFO    Alex Smith    QB  21.0  2018.0       0.0
# 1           1  1.0   1.0  SFO    Alex Smith    QB  21.0  2018.0       0.0
# 2           2  3.0  71.0  TAM    Alex Smith    TE  23.0  2015.0       0.0
# 3           3  3.0  71.0  TAM    Alex Smith    TE  23.0  2015.0       0.0
# 4           4  1.0   2.0  MIA  Ronnie Brown    RB  23.0  2014.0       0.0
#
#    Misc_PB  ...  Vertical  Bench  Broad Jump  3Cone  Shuttle  \
# 0      3.0  ...      32.0    NaN       113.0   6.82     3.96
# 1      3.0  ...       NaN   28.0         NaN    NaN      NaN
# 2      0.0  ...      32.0    NaN       113.0   6.82     3.96
# 3      0.0  ...       NaN   28.0         NaN    NaN      NaN
# 4      1.0  ...      34.0   18.0       117.0   7.10     4.08
#
#                              Drafted (tm/rnd/yr)  drafted_year  \
# 0    San Francisco 49ers / 1st / 1st pick / 2005        2005.0
# ...

# %%
df_pos_each_year = df_merged[df_merged.Rnd < 4.0].groupby(['Year', 'Tm','Pos_x']).size().reset_index(name='cnt')

# %%
teams = list(df_pos_each_year.Tm.unique())
for t in teams:
    temp_df = df_pos_each_year[df_pos_each_year.Tm == t]
    fig = px.line(temp_df, x="Year", y="cnt", color='Pos_x', title = "Team : " + t)
    fig.show()
# Out:
# <div>
#
#
#             <div id="c7b99927-cc1f-41a5-85d6-b84458696f3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c7b99927-cc1f-41a5-85d6-b84458696f3c")) {
#                     Plotly.newPlot(
#                         'c7b99927-cc1f-41a5-85d6-b84458696f3c',
# ...

# %%
# df_pos_each_year = df_merged[df_merged.Rnd < 4.0].groupby(['Year', 'Pos_x']).size().reset_index(name='cnt')

# %%
# fig = px.line(df_pos_each_year, x="Year", y="cnt", color='Pos_x')
# fig.show()

# %%
# df_pos_each_year_all = df_merged.groupby(['Year', 'Pos_x']).size().reset_index(name='cnt')
# fig = px.line(df_pos_each_year_all, x="Year", y="cnt", color='Pos_x')
# fig.show()

# %%
px.line?
